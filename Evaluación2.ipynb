# %%
#Cargamos las librerías a utilizar
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
#Leemos el primer archivo
meteovid = pd.read_excel('meteo-vid-2018.xlsx')

# %%
#Visualizamos la tablla
meteovid.head()
# Out:
#         Date      Time  batt_volt_Min  logger_temp  short_up_Avg  \
# 0 2018-01-06  17:00:00          12.39        28.43         36.15
# 1 2018-01-06  17:30:00          12.27        27.38         22.42
# 2 2018-01-06  18:00:00          12.22        26.30          1.41
# 3 2018-01-06  18:30:00          12.19        25.04         -2.77
# 4 2018-01-06  19:00:00          12.17        23.92         -2.48
#
#    short_dn_Avg  long_up_Avg  long_dn_Avg  cnr4_T_C_Avg  cnr4_T_K_Avg  ...    \
# 0          7.23       -47.65       -13.43         27.69        300.84  ...
# 1          4.48       -56.17       -15.24         26.63        299.78  ...
# 2          0.28       -52.09       -15.60         24.90        298.05  ...
# 3         -0.55       -51.42       -14.43         23.31        296.46  ...
# 4         -0.50       -50.24       -13.61         22.48        295.63  ...
#
#    H. suelo 60  Result2_Avg  T. suelo 60 cm  Result4_Avg  Result5_Avg  \
# 0         0.23         0.04           24.33        75.80         0.04
# 1         0.23         0.04           21.95        71.54         0.04
# 2         0.23         0.04           21.34        70.38         0.04
# 3         0.23         0.04           21.12        70.02         0.04
# 4         0.24         0.04           21.10        70.00         0.04
#
#    Result6_Avg  Result7_Avg  Result8_Avg  Result9_Avg  Riego
# 0        14.16        13.37        14.46        13.46    0.0
# 1        14.10        13.23        14.32        13.81    0.0
# 2        14.31        13.12        14.51        13.84    0.0
# 3        14.38        13.18        14.58        13.94    0.0
# 4        14.41        13.32        14.60        14.11    0.0
#
# [5 rows x 35 columns]

# %%
meteovid.dtypes
# Out:
# Date                datetime64[ns]
# Time                        object
# batt_volt_Min              float64
# logger_temp                float64
# short_up_Avg               float64
# short_dn_Avg               float64
# long_up_Avg                float64
# long_dn_Avg                float64
# cnr4_T_C_Avg               float64
# cnr4_T_K_Avg               float64
# long_up_corr_Avg           float64
# long_dn_corr_Avg           float64
# Rs_net_Avg                 float64
# Rl_net_Avg                 float64
# albedo_Avg                 float64
# Rn_Avg                     float64
# AirTC_Avg                  float64
# RH                         float64
# WS_ms_S_WVT                float64
# WindDir_D1_WVT             float64
# WindDir_SD1_WVT            float64
# Temp_C_Avg(1)              float64
# Temp_C_Avg(2)              float64
# Temp_C_Avg(3)              float64
# Temp_C_Avg(4)              float64
# H. suelo 60                float64
# Result2_Avg                float64
# T. suelo 60 cm             float64
# Result4_Avg                float64
# Result5_Avg                float64
# Result6_Avg                float64
# Result7_Avg                float64
# Result8_Avg                float64
# Result9_Avg                float64
# Riego                      float64
# dtype: object

# %%
df0=pd.DataFrame([])

# %%
df0["MES"] = meteovid["Date"].dt.month
df0["Dia"] = meteovid["Date"].dt.day
df0["VelV"] = meteovid["WS_ms_S_WVT"]
df0["T"] = meteovid["AirTC_Avg"]
df0["RH"] = meteovid["RH"]
df0["Rs"] = meteovid["Rs_net_Avg"]

# %%
df0.head
# Out:
# <bound method NDFrame.head of        MES  Dia  VelV      T     RH      Rs
# 0        1    6  2.33  27.75  20.61   36.01
# 1        1    6  3.12  26.57  25.25   22.34
# 2        1    6  2.54  25.01  26.45    1.40
# 3        1    6  2.01  23.65  29.22   -3.15
# 4        1    6  2.14  22.84  31.08   -2.84
# 5        1    6  1.05  22.02  31.85   -2.23
# 6        1    6  0.81  21.01  34.80   -2.30
# 7        1    6  0.24  20.18  37.47   -2.38
# 8        1    6  1.88  18.20  39.41   -2.78
# 9        1    6  1.73  17.61  41.29   -2.86
# 10       1    6  1.91  16.96  44.21   -2.53
# 11       1    6  2.11  16.56  45.64   -2.47
# 12       1    6  2.09  16.03  46.27   -1.93
# 13       1    6  1.82  16.26  44.49   -0.63
# 14       1    7  1.51  16.51  44.52   -1.16
# 15       1    7  1.52  16.51  43.83   -1.03
# 16       1    7  0.89  16.61  46.82   -1.05
# 17       1    7  1.41  16.07  46.65   -1.06
# 18       1    7  2.10  16.06  46.27   -2.18
# 19       1    7  1.23  15.81  47.76   -1.42
# 20       1    7  1.05  15.03  48.66   -1.26
# 21       1    7  1.09  14.70  49.62   -1.23
# 22       1    7  1.75  14.42  49.73   -1.87
# 23       1    7  1.46  14.76  48.00   -1.45
# 24       1    7  0.82  15.30  47.16   -1.49
# 25       1    7  0.66  13.93  54.51   -2.59
# 26       1    7  1.29  12.90  54.20   -1.07
# 27       1    7  1.76  12.43  52.29   -2.19
# 28       1    7  1.83  14.42  44.72   -1.23
# 29       1    7  2.13  13.53  50.96    0.39
# ...    ...  ...   ...    ...    ...     ...
# 17217   12   31  3.11  12.02  34.32  221.47
# 17218   12   31  3.58  14.29  31.73  267.99
# 17219   12   31  5.08  15.71  35.24  320.31
# 17220   12   31  5.03  16.45  37.54  364.58
# 17221   12   31  4.77  17.19  37.13  398.11
# 17222   12   31  4.65  17.72  36.47  420.79
# 17223   12   31  5.03  18.08  36.24  431.49
# 17224   12   31  4.36  18.56  35.35  426.27
# 17225   12   31  4.49  18.72  34.91  410.03
# 17226   12   31  3.59  19.21  33.45  391.02
# 17227   12   31  4.36  19.43  34.06  363.92
# 17228   12   31  4.64  19.43  34.95  320.87
# 17229   12   31  4.90  19.17  36.20  271.96
# 17230   12   31  4.92  18.79  37.86  213.12
# 17231   12   31  4.87  18.28  41.29  152.74
# 17232   12   31  4.58  17.72  43.40   89.97
# 17233   12   31  4.40  16.76  49.69   29.59
# 17234   12   31  2.65  15.57  53.09   -2.81
# 17235   12   31  1.51  14.37  56.54   -6.24
# 17236   12   31  2.04  13.05  59.76   -5.57
# 17237   12   31  1.71  12.28  61.11   -5.65
# 17238   12   31  1.45  11.28  63.76   -5.49
# 17239   12   31  1.50  10.13  67.37   -4.84
# 17240   12   31  1.42   9.08  70.35   -3.89
# 17241   12   31  1.30   7.92  72.82   -3.69
# 17242   12   31  2.18   8.24  70.48   -4.02
# 17243   12   31  2.00   8.26  67.03   -4.03
# 17244   12   31  2.04   7.88  64.85   -3.90
# 17245   12   31  2.12   7.77  62.43   -3.91
# 17246    1    1  1.33   7.71  63.83   -3.94
#
# [17247 rows x 6 columns]>

# %%
df0["Tmax"] = df0.groupby(["MES"])["T"].transform("max")
df0["Tmin"] = df0.groupby(["MES"])["T"].transform("min")
df0["Tmean"] = df0.groupby(["MES"])["T"].transform("mean")

df0["RHmax"] = df0.groupby(["MES"])["RH"].transform("max")
df0["RHmin"] = df0.groupby(["MES"])["RH"].transform("min")
df0["RHmean"] = df0.groupby(["MES"])["RH"].transform("mean")

df0["Vel"] = df0.groupby(["MES"])["VelV"].transform("mean")
df0["RS"] = df0.groupby(["MES"])["Rs"].transform("mean")


f=len(df0)

lat=[]
long=[]
elev=[]
for i in range (0,f):
    a=28.918611
    o= -111.310639
    e= 101
    lat.append(a)
    long.append(o)
    elev.append(e)
df0["Latitud"] = lat
df0["Longitud"] = long
df0["Elevacion"] = elev

# %%
df0.head
# Out:
# <bound method NDFrame.head of        MES  Dia  VelV      T     RH      Rs   Tmax  Tmin      Tmean  RHmax  \
# 0        1    6  2.33  27.75  20.61   36.01  33.35  0.54  16.963975  91.60
# 1        1    6  3.12  26.57  25.25   22.34  33.35  0.54  16.963975  91.60
# 2        1    6  2.54  25.01  26.45    1.40  33.35  0.54  16.963975  91.60
# 3        1    6  2.01  23.65  29.22   -3.15  33.35  0.54  16.963975  91.60
# 4        1    6  2.14  22.84  31.08   -2.84  33.35  0.54  16.963975  91.60
# 5        1    6  1.05  22.02  31.85   -2.23  33.35  0.54  16.963975  91.60
# 6        1    6  0.81  21.01  34.80   -2.30  33.35  0.54  16.963975  91.60
# 7        1    6  0.24  20.18  37.47   -2.38  33.35  0.54  16.963975  91.60
# 8        1    6  1.88  18.20  39.41   -2.78  33.35  0.54  16.963975  91.60
# 9        1    6  1.73  17.61  41.29   -2.86  33.35  0.54  16.963975  91.60
# 10       1    6  1.91  16.96  44.21   -2.53  33.35  0.54  16.963975  91.60
# 11       1    6  2.11  16.56  45.64   -2.47  33.35  0.54  16.963975  91.60
# 12       1    6  2.09  16.03  46.27   -1.93  33.35  0.54  16.963975  91.60
# 13       1    6  1.82  16.26  44.49   -0.63  33.35  0.54  16.963975  91.60
# 14       1    7  1.51  16.51  44.52   -1.16  33.35  0.54  16.963975  91.60
# 15       1    7  1.52  16.51  43.83   -1.03  33.35  0.54  16.963975  91.60
# 16       1    7  0.89  16.61  46.82   -1.05  33.35  0.54  16.963975  91.60
# 17       1    7  1.41  16.07  46.65   -1.06  33.35  0.54  16.963975  91.60
# 18       1    7  2.10  16.06  46.27   -2.18  33.35  0.54  16.963975  91.60
# 19       1    7  1.23  15.81  47.76   -1.42  33.35  0.54  16.963975  91.60
# 20       1    7  1.05  15.03  48.66   -1.26  33.35  0.54  16.963975  91.60
# 21       1    7  1.09  14.70  49.62   -1.23  33.35  0.54  16.963975  91.60
# 22       1    7  1.75  14.42  49.73   -1.87  33.35  0.54  16.963975  91.60
# 23       1    7  1.46  14.76  48.00   -1.45  33.35  0.54  16.963975  91.60
# 24       1    7  0.82  15.30  47.16   -1.49  33.35  0.54  16.963975  91.60
# 25       1    7  0.66  13.93  54.51   -2.59  33.35  0.54  16.963975  91.60
# 26       1    7  1.29  12.90  54.20   -1.07  33.35  0.54  16.963975  91.60
# 27       1    7  1.76  12.43  52.29   -2.19  33.35  0.54  16.963975  91.60
# 28       1    7  1.83  14.42  44.72   -1.23  33.35  0.54  16.963975  91.60
# 29       1    7  2.13  13.53  50.96    0.39  33.35  0.54  16.963975  91.60
# ...    ...  ...   ...    ...    ...     ...    ...   ...        ...    ...
# 17217   12   31  3.11  12.02  34.32  221.47  31.86 -1.34  14.332823  97.33
# %%
df.head()
# Out:
#    Mes   Tmax  Tmin      Tmean  RHmax  RHmin     RHmean       Vel          RS
# 0    1  33.35  0.54  16.963975   91.6   5.98  38.471432  1.943827  111.861695
# 1    1  33.35  0.54  16.963975   91.6   5.98  38.471432  1.943827  111.861695
# 2    1  33.35  0.54  16.963975   91.6   5.98  38.471432  1.943827  111.861695
# 3    1  33.35  0.54  16.963975   91.6   5.98  38.471432  1.943827  111.861695
# 4    1  33.35  0.54  16.963975   91.6   5.98  38.471432  1.943827  111.861695

# %%
df=df.drop_duplicates()
f=len(df)
df.index = np.arange(0,f)
lat=[]
long=[]
elev=[]
for i in range (0,f):
    a=28.918611
    o= -111.310639
    e= 101
    lat.append(a)
    long.append(o)
    elev.append(e)
df["Latitud"] = lat
df["Longitud"] = long
df["Elevacion"] = elev
# Out:
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
#Creando la gráfica
df
# Out:
#     Mes   Tmax   Tmin      Tmean  RHmax  RHmin     RHmean       Vel  \
# 0     1  33.35   0.54  16.963975  91.60   5.98  38.471432  1.943827
# 1     2  31.47   0.07  17.230275  99.53   6.76  48.168006  1.964189
# 2     3  35.22   3.06  19.282359  89.73   6.76  36.968353  1.926196
# 3     4  36.30   5.43  21.880618  93.40   5.23  40.785667  2.101812
# 4     5  38.18   7.13  23.650034  94.60   8.19  44.233468  2.113918
# 5     6  41.47  13.12  28.416187  98.37   5.34  50.810507  2.154986
# 6     7  44.94  18.71  31.065726  97.00  13.10  57.639805  2.022204
# 7     8  40.24  22.71  30.120894  98.60  30.16  68.868454  1.910853
# 8     9  41.39  19.43  29.661271  98.03  21.32  66.619750  1.790326
# 9    10  35.82  10.23  23.254207  98.47  17.32  68.696082  1.664435
# 10   11  32.39   2.47  16.966396  99.43   8.75  58.085458  1.498097
# 11   12  31.86  -1.34  14.332823  97.33   8.04  58.333938  1.628730
#
#             RS    Latitud    Longitud  Elevacion
# 0   111.861695  28.918611 -111.310639        101
# 1   126.347812  28.918611 -111.310639        101
# 2   170.105269  28.918611 -111.310639        101
# 3   213.415993  28.918611 -111.310639        101
# 4   237.177688  28.918611 -111.310639        101
# 5   224.636062  28.918611 -111.310639        101
# 6   200.421983  28.918611 -111.310639        101
# 7   189.466922  28.918611 -111.310639        101
# 8   183.133271  28.918611 -111.310639        101
# 9   148.386203  28.918611 -111.310639        101
# 10  125.265785  28.918611 -111.310639        101
# 11   99.410793  28.918611 -111.310639        101

# %%
#Creando los gráficos
plt.figure(1, figsize=(9, 6))

plt.plot(df.Mes, df.Tmax)
plt.plot(df.Mes, df.Tmin)
plt.plot(df.Mes, df.Tmean)
plt.title("Variación mensual de las temperaturas mínima y máxima")
plt.ylabel("Temp ºC")
plt.gca().legend(('Tmax','Tmin', "Tmean"))
plt.grid(True)
plt.show()

# %%
plt.figure(1, figsize=(9, 6))

plt.plot(df.Mes, df.RHmean)
plt.plot(df.Mes, df.RHmax)
plt.plot(df.Mes, df.RHmin)
plt.title("Variación mensual de la Humedad Realativa")
plt.ylabel("%")
plt.gca().legend(('RHmean','RHmax',"RHmin"))
plt.grid(True)
plt.show()

# %%
plt.figure(1, figsize=(8, 5))

plt.plot(df.Mes, df.RS)

plt.title("Variación mensual de la Radiación Solar")
plt.ylabel("MJ/m^2/día")
plt.grid(True)
plt.show()

# %%
#Continuando con la segunda parte de la Evaluación2
df2=pd.DataFrame([])

f=len(df0)
jen=[]
val1=[]
val2=[]

for i in range (0,f):
    
    RS=df0.RS[i]
    mean=df0.Tmean[i]
    lati=28.918611
    mn=df0.Tmin[i]
    z=101
    u=df0.VelV[i]
    a=meteovid.albedo_Avg[i]
    RH=df0.RH[i]
    
    e= (0.0252*meteovid.AirTC_Avg[i] + 0.078)*df0.RS[i]
    jen.append(e)
    
    v= 0.0393 * RS * (mean+9.5)**0.5 - 0.19 * RS**0.6 * ( (math.pi/180)*(lati) )**0.15 + 0.0061*(mean+20)*(1.12*mean-mn-2)**0.7
    val1.append(v)
    
    
    if i==0:
        j=df0.Dia[0]
    elif df0.Dia[i] != df0.Dia[i-1]:
        j=j+1
    elif df0.Dia[i] == df0.Dia[i-1]:
        j=j
    
    
    d=1+0.033*math.cos(2*j*math.pi/365)
    
    g=0.409*math.sin(2*j*math.pi/365 - 1.39)
    
    w=math.acos(-math.tan(lati*math.pi/180) * math.tan(g) )
    

    Ra = (24*60/math.pi)*d*( w*math.sin(g)*math.sin(lati*math.pi/180) + math.cos(g)*math.cos(lati*math.pi/180)*math.sin(w))
    
    h= 0.051*(1-a)*RS*(mean+9.5)**0.5 - 2.4*(RS/Ra)**2 + 0.048*(mean+20)*(1- RH/100)*(0.5+0.536*u) + 0.00012*z
    
    val2.append(h)

df2["Mes"]=df0.MES
df2["ET_J&H"] = jen
df2["ET_Valiantzas1"] = val1
df2["ET_Valiantzas4"] = val2

# %%
df2.head()
# Out:
#    Mes     ET_J&H  ET_Valiantzas1  ET_Valiantzas4
# 0    1  86.950096       21.310199       31.362990
# 1    1  83.623777       21.310199       31.780606
# 2    1  79.226270       21.310199       31.328664
# 3    1  75.392546       21.310199       35.576110
# 4    1  73.109225       21.310199       35.315781

# %%
df2["ET_J&H"] = df2.groupby(["Mes"])["ET_J&H"].transform("mean")
df2["ET_Valiantzas1"] = df2.groupby(["Mes"])["ET_Valiantzas1"].transform("mean")
df2["ET_Valiantzas4"] = df2.groupby(["Mes"])["ET_Valiantzas4"].transform("mean")

df2=df2.drop_duplicates()
df2
# Out:
#        Mes      ET_J&H  ET_Valiantzas1  ET_Valiantzas4
# 0        1   56.545212       21.310199       43.165927
# 1214     2   64.715721       24.210628       50.449047
# 2558     3   95.924988       33.834978       67.057178
# 4046     4  134.322228       44.563196       86.068343
# 5486     5  159.853219       51.067272       96.785325
# 6974     6  178.380785       52.063887       99.099546
# 8414     7  172.534524       48.026437       78.859969
# 9902     8  158.592629       44.307655       84.900674
# 11390    9  151.169927       42.835503       87.684736
# 12830   10   98.529331       31.589043       70.496390
# 14318   11   63.328515       23.683415       55.130708
# 15758   12   43.659941       17.784211       38.243952

# %%
#Continuando con la Parte 3 de la Evaluación 2
#Leemos el segundo archivo
flujovid = pd.read_excel('flujos-vid-2018.xlsx')

# %%
flujovid.head()
# Out:
#    Year  DoY  Hour   NEE     LE      H    Rg   Tair  Tsoil     rH   ...     \
# 0  2018    7   0.5  2.56  11.52 -20.04 -0.87  16.51  20.99  43.83   ...
# 1  2018    7   1.0  4.07  15.11  -7.34 -0.97  16.61  21.05  46.82   ...
# 2  2018    7   1.5  0.92   8.61  -9.76 -0.96  16.07  21.09  46.65   ...
# 3  2018    7   2.0  0.41   1.93  -8.55 -2.06  16.06  21.09  46.27   ...
# 4  2018    7   2.5  0.31   6.40  -0.55 -1.32  15.81  21.10  47.76   ...
#
#    Tsoil_fmeth  Tsoil_fwin  PotRad  FP_NEEnight  FP_Temp     E_0    R_ref  \
# 0        -9999       -9999     0.0      -9999.0    16.51  207.66  0.92767
# 1        -9999       -9999     0.0      -9999.0    16.61  207.66  0.92767
# 2        -9999       -9999     0.0      -9999.0    16.07  207.66  0.92767
# 3        -9999       -9999     0.0      -9999.0    16.06  207.66  0.92767
# 4        -9999       -9999     0.0      -9999.0    15.81  207.66  0.92767
#
#       Reco   GPP_f  GPP_fqc
# 0  1.00713 -1.0729        1
# 1  1.01249 -0.9620        1
# 2  0.98371 -1.1643        1
# 3  0.98318 -1.1648        1
# 4  0.96997 -1.4929        1
#
# [5 rows x 94 columns]

# %%
#Creando una nueva memoria
df3=pd.DataFrame([])

df3["RnG"]=flujo["Rg_f"]
df3["ET"]=flujo["LE_f"]
df3["H"]=flujo["H_f"]

df3["Dia"]=flujo["DoY"]
df3["Año"]=flujo["Year"]
df3["Hora"]=flujo["Hour"]

# %%
df3.head()
# Out:
#     RnG     ET      H  Dia   Año  Hora
# 0 -0.87  11.52 -20.04    7  2018   0.5
# 1 -0.97  15.11  -7.34    7  2018   1.0
# 2 -0.96   8.61  -9.76    7  2018   1.5
# 3 -2.06   1.93  -8.55    7  2018   2.0
# 4 -1.32   6.40  -0.55    7  2018   2.5

# %%
df4=pd.DataFrame([])

rng=[]
et=[]
h=[]
dia=[]
año=[]
hora=[]
for i in range (0,len(df3)):
    if df3.Dia[i]<32:
        rng.append(df3.RnG[i])
        et.append(df3.ET[i])
        h.append(df3.H[i])
        año.append(df3.Año[i])
        hora.append(df3.Hora[i])
        dia.append(df3.Dia[i])
        
df4["RnG"] = rng
df4["ET"] = et
df4["H"] = h
df4["Hora"] = hora

# %%
df4.head()
# Out:
#     RnG     ET      H  Hora
# 0 -0.87  11.52 -20.04   0.5
# 1 -0.97  15.11  -7.34   1.0
# 2 -0.96   8.61  -9.76   1.5
# 3 -2.06   1.93  -8.55   2.0
# 4 -1.32   6.40  -0.55   2.5

# %%
df4["RnG"] = df3.groupby(["Hora"])["RnG"].transform("mean")
df4["ET"] = df3.groupby(["Hora"])["ET"].transform("mean")
df4["H"] = df3.groupby(["Hora"])["H"].transform("mean")

# %%
df4=df4.drop_duplicates()
df4.head()
# Out:
#         RnG        ET         H  Hora
# 0 -1.676295  4.328268 -7.451123   0.5
# 1 -1.673203  3.148412 -6.646295   1.0
# 2 -1.621616  4.676462 -7.123287   1.5
# 3 -1.576880  4.483637 -7.540920   2.0
# 4 -1.571114  4.491677 -7.876099   2.5

# %%
#Creando el gráfico
plt.figure(1, figsize=(8, 5))

plt.plot(df4.Hora, df4.RnG)
plt.plot(df4.Hora, df4.ET)
plt.plot(df4.Hora, df4.H)

plt.ylabel("Energía que llega/deja la superficie")
plt.xlabel("Tiempo (Hora)")
plt.gca().legend(('Rn-G','ET',"H"))
plt.grid(True)
plt.show()
